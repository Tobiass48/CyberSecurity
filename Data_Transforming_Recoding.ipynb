# %%
import pandas as pd
import numpy as np

filename = "data/CC_Dataset.csv"
df = pd.read_csv(filename)
# a = df.columns
# df1 = a.to_frame(index=False)
# df1.to_csv("Questions.csv", index=False)

# %%
# # Identify last 25 columns as demographics
# demographic_cols = df.columns[-25:]
#
# rows = []
#
# for col in df.columns:
#     if col in demographic_cols:
#         # Just note demographic variables, don’t try to extract categories
#         rows.append([col, "Demographic variable", None, None, None])
#     else:
#         # Extract unique values for this question
#         unique_vals = df[col].dropna().unique().tolist()
#         # Take up to 4 unique answers
#         unique_vals = [str(v) for v in unique_vals[:4]]
#         # Pad so we always have 4 columns
#         while len(unique_vals) < 4:
#             unique_vals.append(None)
#         rows.append([col] + unique_vals)
#
# # Build result dataframe
# df_unique = pd.DataFrame(rows, columns=["Questions", "Option_1", "Option_2", "Option_3", "Option_4"])
# df_unique.to_csv("data/QA_Unique.csv", index=False)
# df_unique.head()
# Out:
#           Questions             Option_1       Option_2  Option_3  Option_4
# 0              QKEY             100260.0       100588.0  100637.0  101224.0
# 1   DEVICE_TYPE_W49               Tablet   Mobile phone   Desktop      None
# 2          LANG_W49              English        Spanish      None      None
# 3          FORM_W49               Form 2         Form 1      None      None
# 4  SOCMEDIAUSEa_W49  No, do not use this  Yes, use this   Refused      None

# %%
# filename = "data/Questions+Categories.csv"
# df_questions = pd.read_csv(filename)
#
# df_merged = df_questions.merge(
#     df_unique,
#     left_on="ID",
#     right_on="Questions",
#     how="left"
# )
#
# # Drop the duplicate join column
# df_merged = df_merged.drop(columns=["Questions"])
#
# # Save
# df_merged.to_csv("ATP_W49_questions_with_categories_and_unique_answers.csv", index=False)
# print("Saved: ATP_W49_questions_with_categories_and_unique_answers.csv")
# Out:
# Saved: ATP_W49_questions_with_categories_and_unique_answers.csv

# %%
import pandas as pd

# Load the file
df = pd.read_csv("data/Questions+Answers+Options.csv")

# Collect options into a dictionary {ID: [options...]}
options_dict = {}
for _, row in df.iterrows():
    opts = []
    # If file has Option_1 … Option_4 columns
    for col in [c for c in df.columns if c.startswith("Option_")]:
        if not pd.isna(row[col]):
            opts.append(str(row[col]).strip())
    # Or fall back to splitting the single Options field
    if not opts and "Options" in df.columns:
        opts = [o.strip() for o in str(row["Options"]).split("|")]
    options_dict[row["ID"]] = opts

# Print nicely
for qid, opts in options_dict.items():
    print(f"{qid}: {opts}")
# Out:
# DEVICE_TYPE_W49: ['Tablet', 'Mobile phone', 'Desktop']
# LANG_W49: ['English', 'Spanish']
# FORM_W49: ['Form 2', 'Form 1']
# SOCMEDIAUSEa_W49: ['No, do not use this', 'Yes, use this', 'Refused']
# SOCMEDIAUSEb_W49: ['No, do not use this', 'Yes, use this', 'Refused']
# SOCMEDIAUSEc_W49: ['No, do not use this', 'Yes, use this', 'Refused']
# SOCMEDIAUSEd_W49: ['No, do not use this', 'Yes, use this', 'Refused']
# SNSUSER_W49: ['Does not use social media', 'Social media user']
# ELECTFTGSNSINT_W49: ['I am worn out by how many political posts and discussions I see on social media', 'I don’t feel strongly about these posts one way or the other', 'I like seeing lots of political posts and discussions on social media', 'Refused']
# TALKDISASNSINT_W49: ['Stressful and frustrating', 'Interesting and informative', 'Refused']
# TALKCMNSNSINT_W49: ['You have less in common politically than you thought', 'You have more in common politically than you thought', 'Refused']
# ...

# %%
# Define recoding dictionaries

recode_maps = {
    "DEVICE_TYPE_W49": {"Tablet": 0, "Mobile phone": 1, "Desktop": 2},
    "LANG_W49": {"English": 0, "Spanish": 1},
    "FORM_W49": {"Form 1": 0, "Form 2": 1},

    "SOCMEDIAUSEa_W49": {"No, do not use this": 0, "Yes, use this": 1, "Refused": np.nan},
    "SOCMEDIAUSEb_W49": {"No, do not use this": 0, "Yes, use this": 1, "Refused": np.nan},
    "SOCMEDIAUSEc_W49": {"No, do not use this": 0, "Yes, use this": 1, "Refused": np.nan},
    "SOCMEDIAUSEd_W49": {"No, do not use this": 0, "Yes, use this": 1, "Refused": np.nan},
    "SNSUSER_W49": {"Does not use social media": 0, "Social media user": 1},

    "ELECTFTGSNSINT_W49": {
        "I am worn out by how many political posts and discussions I see on social media": 0,
        "I don’t feel strongly about these posts one way or the other": 1,
        "I like seeing lots of political posts and discussions on social media": 2,
        "Refused": np.nan
    },
    "TALKDISASNSINT_W49": {"Stressful and frustrating": 0, "Interesting and informative": 1, "Refused": np.nan},
    "TALKCMNSNSINT_W49": {"You have less in common politically than you thought": 0, "You have more in common politically than you thought": 1, "Refused": np.nan},

    "SECUR1_W49": {"Less secure": 0, "About the same": 1, "More secure": 2, "Refused": np.nan},
    "PRIVACYNEWS1_W49": {"Not at all closely": 0, "Not too closely": 1, "Somewhat closely": 2, "Very closely": 3},

    "HOMEASSIST1_W49": {"No": 0, "Yes": 1, "Refused": np.nan},
    "HOMEASSIST2_W49": {"Not concerned at all": 0, "Not too concerned": 1, "Somewhat concerned": 2, "Very concerned": 3},
    "HOMEASSIST3_W49": {"No": 0, "Yes, on occasion": 1, "Yes, frequently": 2, "Refused": np.nan},
    "HOMEASSIST4_W49": {"Not important at all": 0, "Not too important": 1, "Somewhat important": 2, "Very important": 3},
    "HOMEASSIST5a_W49": {"No": 0, "Yes": 1, "Refused": np.nan},
    "HOMEASSIST5b_W49": {"No": 0, "Yes": 1, "Refused": np.nan},
    "HOMEIOT_W49": {"No": 0, "Yes": 1, "Refused": np.nan},
    "FITTRACK_W49": {"No, do not wear this": 0, "Yes, wear this": 1, "Refused": np.nan},
    "LOYALTY_W49": {"No, do not belong to this": 0, "Yes, belong to this": 1, "Refused": np.nan},
    "DNATEST_W49": {"No, have not used this": 0, "Yes, have used this": 1, "Refused": np.nan},

    "TRACKCO1a_W49": {"Very little of it": 0, "Some of it": 1, "Most of it": 2, "All or almost all of it": 3},
    "TRACKCO1b_W49": {"None of it": 0, "Very little of it": 1, "Some of it": 2, "All or almost all of it": 3},

    "CONCERNCO_W49": {"Not at all concerned": 0, "Not too concerned": 1, "Somewhat concerned": 2, "Very concerned": 3},
    "BENEFITCO_W49": {"Very little": 0, "Some": 1, "A great deal": 2, "Refused": np.nan},
    "CONTROLCO_W49": {"No control": 0, "Very little control": 1, "Some control": 2, "A great deal of control": 3},
    "UNDERSTANDCO_W49": {"Nothing": 0, "Very little": 1, "Some": 2, "A great deal": 3},
    "POSNEGCO_W49": {
        "The potential risks of companies collecting data about me outweigh the benefits I get": 0,
        "The benefits I get from companies collecting data about me outweigh the potential risks": 1,
        "Refused": np.nan
    },
    "ANONYMOUS1CO_W49": {"No, it is not possible": 0, "Yes, it is possible": 1, "Refused": np.nan},

    "TRACKGOV1a_W49": {"None of it": 0, "Some of it": 1, "Most of it": 2, "All or almost all of it": 3},
    "TRACKGOV1b_W49": {"None of it": 0, "Very little of it": 1, "Some of it": 2, "All or almost all of it": 3},
    "CONCERNGOV_W49": {"Not at all concerned": 0, "Not too concerned": 1, "Somewhat concerned": 2, "Very concerned": 3},
    "BENEFITGOV_W49": {"Very little": 0, "Some": 1, "A great deal": 2, "Refused": np.nan},
    "CONTROLGOV_W49": {"No control": 0, "Very little control": 1, "Some control": 2, "Refused": np.nan},
    "UNDERSTANDGOV_W49": {"Nothing": 0, "Very little": 1, "Some": 2, "A great deal": 3},
    "POSNEGGOV_W49": {
        "The potential risks of the government collecting data about me and others outweigh the benefits it can provide": 0,
        "The benefits the government can provide by collecting data about me and others outweigh the potential risks": 1,
        "Refused": np.nan
    },
    "ANONYMOUS1GOV_W49": {"No, it is not possible": 0, "Yes, it is possible": 1, "Refused": np.nan},
    "CONCERNGRPa_W49": {
        "Not concerned": 0,
        "Concerned a little": 1,
        "Concerned a lot": 2,
        "Refused": np.nan
    },
    "CONCERNGRPb_W49": {
        "Not concerned": 0,
        "Concerned a little": 1,
        "Concerned a lot": 2,
        "Refused": np.nan
    },
    "CONCERNGRPc_W49": {
        "Not concerned": 0,
        "Concerned a little": 1,
        "Concerned a lot": 2,
        "Refused": np.nan
    },
    "CONCERNGRPd_W49": {
        "Not concerned": 0,
        "Concerned a little": 1,
        "Concerned a lot": 2,
        "Refused": np.nan
    },
    "CONCERNGRPe_W49": {
        "Not concerned": 0,
        "Concerned a little": 1,
        "Concerned a lot": 2,
        "Refused": np.nan
    },
    "CONCERNGRPf_W49": {
        "Not concerned": 0,
        "Concerned a little": 1,
        "Concerned a lot": 2,
        "Refused": np.nan
    },

    "CONTROLGRPa_W49": {
        "No control": 0,
        "A little control": 1,
        "A lot of control": 2,
        "Refused": np.nan
    },
    "CONTROLGRPb_W49": {
        "No control": 0,
        "A little control": 1,
        "A lot of control": 2,
        "Offline: does not have internet": np.nan
    },
    "CONTROLGRPc_W49": {
        "No control": 0,
        "A little control": 1,
        "A lot of control": 2,
        "Refused": np.nan
    },
    "CONTROLGRPd_W49": {
        "No control": 0,
        "A little control": 1,
        "A lot of control": 2,
        "Refused": np.nan
    },
    "CONTROLGRPe_W49": {
        "No control": 0,
        "A little control": 1,
        "A lot of control": 2,
        "Offline: does not have internet": np.nan
    },
    "CONTROLGRPf_W49": {
        "No control": 0,
        "A little control": 1,
        "A lot of control": 2,
        "Refused": np.nan
    },
        "PP1_W49": {
        "Less frequently": 0,
        "About once a month": 1,
        "About once a week": 2,
        "Almost daily": 3
    },
    "PP2_W49": {
        "Never": 0,
        "Sometimes": 1,
        "Often": 2,
        "Always": 3
    },
    "PP3_W49": {
        "Glance over it without reading it closely": 0,
        "Read it part of the way through": 1,
        "Read it all the way through": 2,
        "Refused": np.nan
    },
    "PP4_W49": {
        "Not at all": 0,
        "Very little": 1,
        "Some": 2,
        "A great deal": 3
    },
    "PP5a_W49": {
        "Not confident at all": 0,
        "Not too confident": 1,
        "Somewhat confident": 2,
        "Very confident": 3
    },
    "PP5b_W49": {
        "Not confident at all": 0,
        "Not too confident": 1,
        "Somewhat confident": 2,
        "Very confident": 3
    },
    "PP5c_W49": {
        "Not confident at all": 0,
        "Not too confident": 1,
        "Somewhat confident": 2,
        "Very confident": 3
    },
    "PP5d_W49": {
        "Not confident at all": 0,
        "Not too confident": 1,
        "Somewhat confident": 2,
        "Refused": np.nan
    },
    "PP5e_W49": {
        "Not confident at all": 0,
        "Not too confident": 1,
        "Somewhat confident": 2,
        "Very confident": 3
    },
    "PP6a_W49": {
        "Not comfortable at all": 0,
        "Not too comfortable": 1,
        "Somewhat comfortable": 2,
        "Very comfortable": 3
    },
    "PP6b_W49": {
        "Not comfortable at all": 0,
        "Not too comfortable": 1,
        "Somewhat comfortable": 2,
        "Very comfortable": 3
    },
    "PP6c_W49": {
        "Not comfortable at all": 0,
        "Not too comfortable": 1,
        "Somewhat comfortable": 2,
        "Very comfortable": 3
    },
        "PRIVACYREG_W49": {
        "Not at all": 0,
        "Very little": 1,
        "Some": 2,
        "A great deal": 3
    },
    "GOVREGV1_W49": {
        "Less regulation": 0,
        "About the same amount": 1,
        "More regulation": 2,
        "Refused": np.nan
    },
    "GOVREGV2_W49": {
        "Better tools for allowing people to control their personal information themselves": 0,
        "Stronger laws governing what companies can and cannot do with people’s personal information": 1,
        "Refused": np.nan
    },
    "SHARE1_W49": {
        "No, have not done this": 0,
        "Yes, have done this": 1,
        "Refused": np.nan
    },
        "KNOW1_W49": {
        "Not sure": np.nan,
        "Can track your visits and activity on the site": 1,
        "Can see the content of all the files on the device you are using": 0,
        "Will automatically prompt you to update your web browser software if it is out of date": 0
    },
    "KNOW2_W49": {
        "Not sure": np.nan,
        "Allowing companies to purchase advertisements on their platforms": 1,
        "Providing consulting services to corporate clients": 0,
        "Exclusive licensing deals with internet service providers and cellphone manufacturers": 0
    },
    "KNOW3_W49": {
        "Not sure": np.nan,
        "Has created a contract between itself and its users about how it will use their data": 0,
        "Will not share its users’ personal information with third parties": 0,
        "Does not retain any personally identifying information about its users": 0
    },
    "KNOW4_W49": {
        "Not sure": np.nan,
        "The site has been verified as trustworthy": 0,
        "Information entered into the site is encrypted": 1,
        "Refused": np.nan
    },
    "KNOW5_W49": {
        "All of the above": 0,
        "In an email": 1,
        "Not sure": np.nan,
        "None of the above": 0
    },
    "KNOW6_W49": {
        "Not sure": np.nan,
        "WhatsApp and Instagram": 1,
        "Twitter and Instagram": 0,
        "Twitter and Snapchat": 0
    },
    "KNOW7_W49": {
        "Not sure": np.nan,
        "Internet service providers should treat all traffic on their networks equally": 1,
        "Social media platforms must give equal visibility to conservative and liberal points of view": 0,
        "The government cannot censor online speech": 0
    },
    "KNOW8_W49": {
        "Not sure": np.nan,
        "The group that runs their company’s internal computer network": 0,
        "The websites they visit while in private browsing mode": 1,
        "A coworker who uses the same computer": 0
    },
    "KNOW9_W49": {
        "All of the above": 0,
        "Picture of captcha": 0,
        "Not sure": np.nan,
        "Picture of 2-step code": 1
    },
    "KNOW10_W49": {
        "Not sure": np.nan,
        "Sergey Brin, co-founder of Google": 0,
        "Jack Dorsey, co-founder of Twitter": 1,
        "Travis Kalanick, co-founder of Uber": 0
    },
    "TOTALKNOW_W49": {
        "0": 0,
        "1": 1,
        "4": 4,
        "5": 5
    },
        "PWMAN_W49": {"No": 0, "Yes": 1, "Refused": np.nan},
    "PWMAN2_W49": {
        "Don’t know what that is": np.nan,
        "Too expensive": np.nan,
        "Don’t need it": np.nan,
        "Other reason": np.nan
    },
    "SMARTPHONE_W49": {"No": 0, "Yes": 1, "Refused": np.nan},
    "SMARTAPP_W49": {
        "Never install app updates": 0,
        "Update them yourself whenever it’s convenient": 1,
        "Update them yourself as soon as you are notified a new version is available": 2,
        "Set them to update automatically": 3
    },
        "PUBLICDATA_W49": {
        "Keep things about themselves that might be potentially damaging from being searchable online": 0,
        "Discover potentially useful information about others": 1,
        "Refused": np.nan
    },
    "RTBFa_W49": {
        "No, should not be able to remove this from online searches": 0,
        "Yes, should be able to remove this from online searches": 1,
        "Refused": np.nan
    },
    "RTBFb_W49": {
        "No, should not be able to remove this from online searches": 0,
        "Yes, should be able to remove this from online searches": 1,
        "Refused": np.nan
    },
    "RTBFc_W49": {
        "No, should not be able to remove this from online searches": 0,
        "Yes, should be able to remove this from online searches": 1,
        "Refused": np.nan
    },
    "RTBFd_W49": {
        "No, should not be able to remove this from online searches": 0,
        "Yes, should be able to remove this from online searches": 1,
        "Refused": np.nan
    },
    "RTDa_W49": {
        "No, should not have  the right to have this deleted": 0,
        "Yes, should have the right to have this deleted": 1,
        "Refused": np.nan
    },
    "RTDb_W49": {
        "No, should not have  the right to have this deleted": 0,
        "Yes, should have the right to have this deleted": 1,
        "Refused": np.nan
    },
    "RTDc_W49": {
        "No, should not have  the right to have this deleted": 0,
        "Yes, should have the right to have this deleted": 1,
        "Refused": np.nan
    },
    "RTDd_W49": {
        "No, should not have  the right to have this deleted": 0,
        "Yes, should have the right to have this deleted": 1,
        "Refused": np.nan
    },
        "PROFILE1_W49": {
        "Nothing at all": 0,
        "A little": 1,
        "A lot": 2,
        "Refused": np.nan
    },
    "PROFILE2_W49": {
        "Not sure": np.nan,
        "Some of them": 0,
        "Most of them": 1,
        "All of them": 2
    },
    "PROFILE3_W49": {
        "No": 0,
        "Yes, on occasion": 1,
        "Yes, frequently": 2,
        "Not sure": np.nan
    },
    "PROFILE4_W49": {
        "Not at all": 0,
        "Not too much": 1,
        "Somewhat": 2,
        "A great deal": 3
    },
    "PROFILE5_W49": {
        "Not well at all": 0,
        "Not too well": 1,
        "Somewhat well": 2,
        "Very well": 3
    },
    "DATAUSEa_W49": {"Unacceptable": 0, "Acceptable": 1, "Not sure": np.nan, "Refused": np.nan},
    "DATAUSEb_W49": {"Unacceptable": 0, "Acceptable": 1, "Not sure": np.nan, "Refused": np.nan},
    "DATAUSEc_W49": {"Unacceptable": 0, "Acceptable": 1, "Not sure": np.nan, "Refused": np.nan},
    "DATAUSEd_W49": {"Unacceptable": 0, "Acceptable": 1, "Not sure": np.nan, "Refused": np.nan},
    "DATAUSEe_W49": {"Unacceptable": 0, "Acceptable": 1, "Not sure": np.nan, "Refused": np.nan},
    "DATAUSEf_W49": {"Unacceptable": 0, "Acceptable": 1, "Not sure": np.nan, "Refused": np.nan},
        "FACE1_W49": {
        "Nothing at all": 0,
        "A little": 1,
        "A lot": 2,
        "Refused": np.nan
    },
    "FACE2a_W49": {
        "Not effective at all": 0,
        "Not too effective": 1,
        "Somewhat effective": 2,
        "Very effective": 3
    },
    "FACE2b_W49": {
        "Not effective at all": 0,
        "Not too effective": 1,
        "Somewhat effective": 2,
        "Very effective": 3
    },
    "FACE2c_W49": {
        "Not effective at all": 0,
        "Not too effective": 1,
        "Somewhat effective": 2,
        "Very effective": 3
    },
    "FACE3a_W49": {
        "Not at all": 0,
        "Not too much": 1,
        "Somewhat": 2,
        "A great deal": 3
    },
    "FACE3b_W49": {
        "Not at all": 0,
        "Not too much": 1,
        "Somewhat": 2,
        "A great deal": 3
    },
    "FACE3c_W49": {
        "Not at all": 0,
        "Not too much": 1,
        "Somewhat": 2,
        "A great deal": 3
    },
    "FACE4a_W49": {
        "Unacceptable": 0,
        "Acceptable": 1,
        "Not sure": np.nan,
        "Refused": np.nan
    },
    "FACE4b_W49": {
        "Unacceptable": 0,
        "Acceptable": 1,
        "Not sure": np.nan,
        "Refused": np.nan
    },
    "FACE4c_W49": {
        "Unacceptable": 0,
        "Acceptable": 1,
        "Not sure": np.nan,
        "Refused": np.nan
    },
    "FACE4d_W49": {
        "Unacceptable": 0,
        "Acceptable": 1,
        "Not sure": np.nan,
        "Refused": np.nan
    },
       "DB1a_W49": {"No": 0, "Yes": 1, "Refused": np.nan},
    "DB1b_W49": {"No": 0, "Yes": 1, "Offline: does not have internet": np.nan, "Refused": np.nan},
    "DB1c_W49": {"No": 0, "Yes": 1, "Refused": np.nan}
}


# Example: apply these recodings to your dataframe
df = pd.read_csv("data/CC_Dataset.csv")

for col, mapping in recode_maps.items():
    if col in df.columns:
        df[col + "_num"] = df[col].map(mapping)

df.head()
# Save recoded dataset
df.to_csv("survey_data_recoded.csv", index=False)
# Out:
# C:\Users\tobia\AppData\Local\Temp\ipykernel_39956\4124363518.py:468: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col + "_num"] = df[col].map(mapping)
# C:\Users\tobia\AppData\Local\Temp\ipykernel_39956\4124363518.py:468: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col + "_num"] = df[col].map(mapping)
# ...

# %%
# Load questions file
qa_df = pd.read_csv("data/Questions+Answers+Options.csv")

# Make a lookup column with coding schemes
coding_info = []
for _, row in qa_df.iterrows():
    qid = row["ID"]
    if qid in recode_maps:
        coding_info.append(str(recode_maps[qid]))
    else:
        coding_info.append(None)

qa_df["Coding_Scheme"] = coding_info

# Save back to CSV
qa_df.to_csv("Questions+Answers+Options_with_coding.csv", index=False)

print("Saved: Questions+Answers+Options_with_coding.csv")
# Out:
# Saved: Questions+Answers+Options_with_coding.csv

# %%
# # List of variables of interest (numeric columns)
# vars_list = [
#     "CONCERNCO_W49_num","BENEFITCO_W49_num","POSNEGCO_W49_num",
#     "TRACKCO1a_W49_num","TRACKCO1b_W49_num","CONTROLCO_W49_num","UNDERSTANDCO_W49_num","ANONYMOUS1CO_W49_num",
#     "CONCERNGOV_W49_num","BENEFITGOV_W49_num","POSNEGGOV_W49_num",
#     "TRACKGOV1a_W49_num","TRACKGOV1b_W49_num","CONTROLGOV_W49_num","UNDERSTANDGOV_W49_num","ANONYMOUS1GOV_W49_num"
# ]
#
# # Subset dataframe
# df_sub = df[vars_list]
#
# # Drop rows where all of these are NaN
# df_sub = df_sub.dropna(how="all", subset=vars_list)
#
# # Save cleaned dataframe
# df_sub.to_csv("survey_data_surveillance_subset.csv", index=False)
#
# df_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4269 entries, 0 to 4271
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CONCERNCO_W49_num      2135 non-null   float64
#  1   BENEFITCO_W49_num      1642 non-null   float64
#  2   POSNEGCO_W49_num       2104 non-null   float64
#  3   TRACKCO1a_W49_num      2053 non-null   float64
#  4   TRACKCO1b_W49_num      1715 non-null   float64
#  5   CONTROLCO_W49_num      2136 non-null   float64
#  6   UNDERSTANDCO_W49_num   2130 non-null   float64
#  7   ANONYMOUS1CO_W49_num   2129 non-null   float64
#  8   CONCERNGOV_W49_num     2122 non-null   float64
#  9   BENEFITGOV_W49_num     1384 non-null   float64
#  10  POSNEGGOV_W49_num      2061 non-null   float64
#  11  TRACKGOV1a_W49_num     1798 non-null   float64
#  12  TRACKGOV1b_W49_num     1865 non-null   float64
#  13  CONTROLGOV_W49_num     2060 non-null   float64
# ...
